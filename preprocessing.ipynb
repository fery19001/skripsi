# %% [markdown]
# #### Modules

# %%
import pandas as pd
import numpy as np

import json
import re
import string
from datetime import datetime

# %% [markdown]
# #### Importing Data

# %%
data = json.load(open('./data/finalDataFixREVISI.json'))

# %%
df = pd.json_normalize(data)

# %% [markdown]
# #### Data Lookup

# %%
df.columns
# Out:
# Index(['text', 'hashtags', 'created_at', 'reference_type', 'lang',
#        'users.username', 'users.following', 'users.tweets', 'users.location',
#        'users.verified', 'metrics.retweets', 'metrics.replies',
#        'metrics.quotes', 'metrics.impressions', 'entities.mentions',
#        'entities.url title', 'places.name', 'places.place_type',
#        'places.country', 'places.country_code'],
#       dtype='object')

# %%
df.shape
# Out:
# (312463, 20)

# %% [markdown]
# #### Data Cleaning #1

# %%
df.head(4)
# Out:
#                                                 text hashtags  \
# 0  RT @geloraco: Buzzer Kasihan 2000 Karyawan Hol...     None
# 1  @zomet13 Emangnya kamu belain waktu 2000 karya...     None
# 2  RT @geloraco: Ribuan Pegawai Terancam PHK, Pol...     None
# 3  RT @geloraco: Buzzer Kasihan 2000 Karyawan Hol...     None
#
#                  created_at reference_type lang users.username  \
# 0  2022-06-29T23:56:26.000Z    [retweeted]   in         ZefriF
# 1  2022-06-29T23:53:44.000Z   [replied_to]   in       GYatmoko
# 2  2022-06-29T23:51:39.000Z    [retweeted]   in  joko_wijiyono
# 3  2022-06-29T23:50:04.000Z    [retweeted]   in      drysblack
#
#    users.following  users.tweets          users.location users.verified  \
# 0             23.0         110.0                    None          False
# 1          15567.0       35473.0               Indonesia          False
# 2             70.0        6555.0                    None          False
# 3             42.0        2297.0  Pulo Gadung, Indonesia          False
#
#    metrics.retweets  metrics.replies  metrics.quotes  metrics.impressions  \
# 0               635                0               0                    0
# 1                 0                1               0                    0
# 2               123                0               0                    0
# 3               635                0               0                    0
#
#   entities.mentions entities.url title places.name places.place_type  \
# 0        [geloraco]                 []        None              None
# 1         [zomet13]               None        None              None
# 2        [geloraco]                 []        None              None
# 3        [geloraco]                 []        None              None
#
#   places.country places.country_code
# 0           None                None
# 1           None                None
# 2           None                None
# 3           None                None

# %%
def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

def cleanTweet(tweet):
    tweet = re.sub("(\w*\d\w*)", "", tweet)
    tweet = re.sub("(RT )|(\\b[A-Za-z] \\b|\\b [A-Za-z]\\b)|(&amp)|(https?:\/\/\S*)|(@([a-zA-Z0-9_]{1,50}))|(#([a-zA-Z0-9_]{1,50})|(\d+))", "", tweet)
    tweet = re.sub("(,)|(\n)|(…)|(”)|(“)|(²)|(×)|(⏬)|(„)|(•)|(–)|(‼)|(⁉)|(©)|(⁣⋱)|(⋮)|(⋰)|(⋯)|(¸)|(¨)|(’)|(‘)|(—)", " ", tweet)
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    tweet = remove_emojis(tweet)
    tweet = tweet.strip()
    tweet = tweet.lower()
    tweet = ' '.join(tweet.split())
    
    return tweet

# %%
df['entities.mentions'], df['entities.url title'] = df['entities.mentions'].apply(lambda d: d if isinstance(d, list) else []), df['entities.url title'].apply(lambda d: d if isinstance(d, list) else [])
df.sort_values(by='created_at', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df['created_at'] = df['created_at'].apply(lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%S.%f%z').strftime('%d-%m-%Y %H:%M:%S'))
df['text'] = df['text'].apply(lambda x: cleanTweet(x))
df = df[df['lang'] == 'in'].reset_index(drop=True)
df['users.verified'] = df['users.verified'].fillna('False')
df['hashtags'], df['entities.mentions'] = df['hashtags'].apply(lambda x: list(map(lambda y: y.lower(), x)) if x is not None else None), df['entities.mentions'].apply(lambda x: list(map(lambda y: y.lower(), x)) if x is not None else None)

df.replace(to_replace='', value=None, inplace=True)
df.dropna(subset=['text'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.tail(2)
# Out:
#                                                      text hashtags  \
# 311623  sebelumnya dia minta duit dan minta jajan ke a...     None
# 311624  sebelumnya dia minta duit dan minta jajan ke a...     None
#
#                  created_at reference_type lang  users.username  \
# 311623  30-03-2023 23:52:35    [retweeted]   in         njaesab
# 311624  30-03-2023 23:56:59    [retweeted]   in  sipalingorange
#
#         users.following  users.tweets        users.location users.verified  \
# 311623            946.0       16434.0  Sidoarjo, jawa timur          False
# 311624            287.0        6167.0                  None          False
#
#         metrics.retweets  metrics.replies  metrics.quotes  \
# 311623               257                0               0
# 311624               257                0               0
#
#         metrics.impressions entities.mentions entities.url title places.name  \
# 311623                    0      [tanyakanrl]                 []        None
# 311624                    0      [tanyakanrl]                 []        None
#
#        places.place_type places.country places.country_code
# 311623              None           None                None
# 311624              None           None                None

# %%
df.shape
# Out:
# (311625, 20)

# %%
new_df = df.drop_duplicates(subset=['text']).reset_index(drop=True)
tweets_w_hashtags = pd.DataFrame(new_df[new_df.hashtags.notnull()]).reset_index(drop=True)
hashtags_wo_rt = pd.DataFrame(new_df[new_df.reference_type.isnull()]).reset_index(drop=True)
tweets_w_hashtags_wo_rt = pd.DataFrame(hashtags_wo_rt[hashtags_wo_rt.hashtags.notnull()]).reset_index(drop=True)

# %%
print(f"Tweets without text duplicates: {len(new_df)}")
print(f"Tweets with hashtags: {len(tweets_w_hashtags)}")
print(f"Pure tweets (w/o RT/QT/Reply): {len(hashtags_wo_rt)}")
print(f"Pure tweets (w/o RT/QT/Reply) with hashtags: {len(tweets_w_hashtags_wo_rt)}")
# Out:
# Tweets without text duplicates: 98743
# Tweets with hashtags: 11867
# Pure tweets (w/o RT/QT/Reply): 40867
# Pure tweets (w/o RT/QT/Reply) with hashtags: 9762

# %%
new_df['hashtags'][1], new_df['reference_type'][1]
# Out:
# (None, ['retweeted'])

# %%
new_df.shape
# Out:
# (98743, 20)

# %%
tweets_w_hashtags
# Out:
#                                                     text  \
# 0      banding ukt turunnya gaji hingga phk banyak di...
# 1      ada suara kemarin tentang pembubaran nasib phk...
# 2      di tangan panas skidipap lembaga eijkman berha...
# 3      dd biaya pernikahan dibwh tahun sakit tdk puny...
# 4      mengakhiri tahun dengan menyampaikan laporan k...
# ...                                                  ...
# 11862  sudah diphk nggak dapet pesangon pula pil pahi...
# 11863  kembali pada isu utama yang lebih berbahaya ya...
# 11864  maja people ada kabar kurang enak dari perusah...
# 11865  startup berbasis arisan online shox rumahan ba...
# 11866  disney hapus divisi metaverse di putaran perta...
#
#                                                 hashtags           created_at  \
# 0      [himitpens, kabinetagnibrata, forzainformatika...  01-01-2022 14:03:02
# 1                                                 [brin]  02-01-2022 08:00:54
# 2                                        [kumparansains]  02-01-2022 08:40:35
# 3                            [danadarurat, shilafintips]  02-01-2022 09:08:39
# 4                                         [dprd_cilegon]  02-01-2022 15:31:03
# ...                                                  ...                  ...
# 11862                                    [terminalmojok]  30-03-2023 08:45:44
# 11863                                       [usuttuntas]  30-03-2023 08:59:55
# 11864  [majalabs, waltdisney, disney, metaverse, web3...  30-03-2023 10:00:12
# 11865           [bisnisupdate, update, bisnis, oneliner]  30-03-2023 13:01:31
# 11866                                       [tempotekno]  30-03-2023 15:20:12
#
#       reference_type lang  users.username  users.following  users.tweets  \
# 0               None   in       himitpens            156.0        4960.0
# 1           [quoted]   in          dir1ku           3254.0       65752.0
# 2           [quoted]   in           awLdh            666.0       82112.0
# 3               None   in  bregaswaras_id             16.0       15287.0
# 4               None   in       faturohmi            423.0        7490.0
# ...              ...  ...             ...              ...           ...
# 11862           None   in      mojokdotco            489.0      132062.0
# 11863           None   in  Neilarmstronkk            782.0        3182.0
# 11864           None   in    majalabs_xyz             79.0        1176.0
# 11865           None   in        kumparan              3.0      953869.0
# 11866           None   in      tempodotco             28.0     1163490.0
#
#          users.location users.verified  metrics.retweets  metrics.replies  \
# 0              Surabaya          False                 0                1
# 1                Malang          False                 1                0
# 2                  None          False                 0                1
# 3                  None          False                 0                0
# 4       Cilegon, banten          False                 1                1
# ...                 ...            ...               ...              ...
# 11862  redaksi@mojok.co          False                 1                0
# 11863               Bdg          False                 0                0
# 11864         Indonesia          False                 0                1
# 11865              None           True                 0                0
# 11866         Indonesia          False                 0                0
#
#        metrics.quotes  metrics.impressions entities.mentions  \
# 0                   0                    0                []
# 1                   0                    0  [brin_indonesia]
# 2                   0                    0                []
# 3                   0                    0                []
# 4                   0                    0        [gerindra]
# ...               ...                  ...               ...
# 11862               0                 2535                []
# 11863               0                   37                []
# 11864               0                   40                []
# 11865               1                 1963                []
# 11866               0                 1475                []
#
#                                       entities.url title      places.name  \
# 0                                                     []             None
# 1                                                     []             None
# 2                                                     []  Jati, Indonesia
# 3                                                     []             None
# 4                                                     []             None
# ...                                                  ...              ...
# 11862  [Balada Korban PHK Sepihak Shox Rumahan Merebu...             None
# 11863                                                 []             None
# 11864                                                 []             None
# 11865                                                 []             None
# 11866  [Disney Hapus Divisi Metaverse di Putaran Pert...             None
#
#       places.place_type places.country places.country_code
# 0                  None           None                None
# 1                  None           None                None
# 2                  city      Indonesia                  ID
# 3                  None           None                None
# 4                  None           None                None
# ...                 ...            ...                 ...
# 11862              None           None                None
# 11863              None           None                None
# 11864              None           None                None
# 11865              None           None                None
# 11866              None           None                None
#
# [11867 rows x 20 columns]

# %%
df.to_csv('./data/initial_data_REVISi.csv', index=False)
new_df.to_csv('./data/data_non_duplicate_tweets_REVISI.csv', index=False)
